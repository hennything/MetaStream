# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeRegressor

import sys
sys.path.append("..")
from meta_stream import MetaStream

# %%
df = pd.read_csv("../../data/electricity-normalized.csv")
df = df[['period', 'nswprice', 'nswdemand', 'vicprice', 'vicdemand', 'transfer']]

# %%
# NOTE: list of regression algorithms
models =    [
            SVR(),
            RandomForestRegressor(random_state=42),
            LinearRegression(),
            Ridge(),
            GradientBoostingRegressor(random_state=42),
            DecisionTreeRegressor()
            ]

# %%
model_names = {
    type(SVR()).__name__: 'SVR',
    type(RandomForestRegressor()).__name__: 'RF',
    type(LinearRegression()).__name__: 'LR',
    type(Ridge()).__name__: 'RIDGE',
    type(GradientBoostingRegressor()).__name__: 'GBR',
    type(DecisionTreeRegressor()).__name__: 'DTR',
}

# %% [markdown]
# Parameter settings for MetaStream (considering a meta-level window size of 200)

# %%
base_data_window = 672
base_delay_window = 0
base_sel_window_size = 24
meta_data_window = 200
threshold = 0.1

# %%
pair_list = []
metastream_score = []
default_score = []

# %%
meta_learner = RandomForestClassifier()
for pair in combinations(models, 2):
    reg1_name = type(pair[0]).__name__
    reg2_name = type(pair[1]).__name__
    print(f'Regressor pair: {reg1_name}, {reg2_name}')
    
    metas = MetaStream(meta_learner, pair, base_data_window, base_delay_window, base_sel_window_size, meta_data_window, strategy='tie', default=True, ensemble=True, pairs=True, threshold=threshold)
    metas.base_train(data=df, target='nswdemand')
    metas.meta_train(data=df, target='nswdemand')
    
    metas.print_results()
    base, meta = metas.get_results()
    
    pair_list.append(f'{model_names[reg1_name]}/{model_names[reg2_name]}')
    metastream_score.append(meta['recommended'])
    default_score.append(meta['default'])
    
    print('######################################################################')
# Out:
# Regressor pair: SVR, RandomForestRegressor
# Mean score Recommended 0.763+-2.051
# Meta-level score Recommended 0.223
# Mean score default 0.748+-3.578
# Meta-level score default 0.184
# Mean score ensemble 1.324+-4.451
# Mean score reg 1. 3.270
# Mean score reg 2. 0.748
# ######################################################################
# Regressor pair: SVR, LinearRegression
# Mean score Recommended 3.270+-12.671
# Meta-level score Recommended 0.419
# Mean score default 3.270+-12.671
# Meta-level score default 0.419
# Mean score ensemble 4.983+-26.314
# Mean score reg 1. 3.270
# Mean score reg 2. 2.816
# ######################################################################
# Regressor pair: SVR, Ridge
# Mean score Recommended 3.270+-12.671
# Meta-level score Recommended 0.321
# Mean score default 3.270+-12.671
# Meta-level score default 0.321
# Mean score ensemble 13.685+-85.284
# Mean score reg 1. 3.270
# Mean score reg 2. 5.390
# ######################################################################
# Regressor pair: SVR, GradientBoostingRegressor
# Mean score Recommended 0.773+-2.164
# Meta-level score Recommended 0.158
# Mean score default 0.722+-1.856
# Meta-level score default 0.139
# Mean score ensemble 1.330+-3.204
# Mean score reg 1. 3.270
# Mean score reg 2. 0.722
# ######################################################################
# Regressor pair: SVR, DecisionTreeRegressor
# Mean score Recommended 0.617+-0.975
# Meta-level score Recommended 0.381
# Mean score default 0.608+-0.964
# Meta-level score default 0.378
# Mean score ensemble 1.039+-2.101
# Mean score reg 1. 3.270
# Mean score reg 2. 0.606
# ######################################################################
# Regressor pair: RandomForestRegressor, LinearRegression
# Mean score Recommended 0.778+-3.719
# Meta-level score Recommended 0.147
# Mean score default 0.748+-3.578
# Meta-level score default 0.136
# Mean score ensemble 1.410+-3.644
# Mean score reg 1. 0.748
# Mean score reg 2. 2.816
# ######################################################################
# Regressor pair: RandomForestRegressor, Ridge
# Mean score Recommended 0.825+-3.727
# Meta-level score Recommended 0.137
# Mean score default 0.748+-3.578
# Meta-level score default 0.113
# Mean score ensemble 2.041+-4.646
# Mean score reg 1. 0.748
# Mean score reg 2. 5.390
# ######################################################################
# Regressor pair: RandomForestRegressor, GradientBoostingRegressor
# Mean score Recommended 0.716+-1.843
# Meta-level score Recommended 0.569
# Mean score default 0.722+-1.856
# Meta-level score default 0.534
# Mean score ensemble 0.713+-1.895
# Mean score reg 1. 0.748
# Mean score reg 2. 0.722
# ######################################################################
# Regressor pair: RandomForestRegressor, DecisionTreeRegressor
# Mean score Recommended 0.744+-3.607
# Meta-level score Recommended 0.454
# Mean score default 0.748+-3.578
# Meta-level score default 0.189
# Mean score ensemble 0.630+-1.362
# Mean score reg 1. 0.748
# Mean score reg 2. 0.610
# ######################################################################
# Regressor pair: LinearRegression, Ridge
# Mean score Recommended 3.687+-7.762
# Meta-level score Recommended 0.695
# Mean score default 2.816+-5.509
# Meta-level score default 0.459
# Mean score ensemble 3.886+-7.666
# Mean score reg 1. 2.816
# Mean score reg 2. 5.390
# ######################################################################
# Regressor pair: LinearRegression, GradientBoostingRegressor
# Mean score Recommended 0.722+-1.856
# Meta-level score Recommended 0.110
# Mean score default 0.722+-1.856
# Meta-level score default 0.110
# Mean score ensemble 1.699+-5.042
# Mean score reg 1. 2.816
# Mean score reg 2. 0.722
# ######################################################################
# Regressor pair: LinearRegression, DecisionTreeRegressor
# Mean score Recommended 0.608+-0.956
# Meta-level score Recommended 0.313
# Mean score default 0.605+-0.974
# Meta-level score default 0.312
# Mean score ensemble 1.150+-2.685
# Mean score reg 1. 2.816
# Mean score reg 2. 0.606
# ######################################################################
# Regressor pair: Ridge, GradientBoostingRegressor
# Mean score Recommended 0.744+-1.915
# Meta-level score Recommended 0.098
# Mean score default 0.722+-1.856
# Meta-level score default 0.089
# Mean score ensemble 2.678+-7.167
# Mean score reg 1. 5.390
# Mean score reg 2. 0.722
# ######################################################################
# Regressor pair: Ridge, DecisionTreeRegressor
# Mean score Recommended 0.618+-1.034
# Meta-level score Recommended 0.261
# Mean score default 0.604+-0.959
# Meta-level score default 0.260
# Mean score ensemble 1.515+-2.917
# Mean score reg 1. 5.390
# Mean score reg 2. 0.621
# ######################################################################
# Regressor pair: GradientBoostingRegressor, DecisionTreeRegressor
# Mean score Recommended 0.715+-1.848
# Meta-level score Recommended 0.283
# Mean score default 0.722+-1.856
# Meta-level score default 0.187
# Mean score ensemble 0.651+-1.482
# Mean score reg 1. 0.722
# Mean score reg 2. 0.609
# ######################################################################

# %%
bar_width = 0.3
bar_locs = np.arange(len(pair_list))

plt.figure(figsize=(15,10))
plt.bar(bar_locs, metastream_score, width=bar_width, color='r', label='MetaStream')
plt.bar(bar_locs+bar_width, default_score, width=bar_width, color='b', label='Default')

plt.xticks(bar_locs+bar_width/2, pair_list, fontsize=14, rotation=90)
plt.xlabel('Regressor pairs', fontsize=20)

plt.yticks(fontsize=14)
plt.ylim(0, 1)
plt.ylabel('Meta-level error rate', fontsize=20)

plt.legend(loc='best', borderpad=1, fontsize=15)
plt.show()
