# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import combinations

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeRegressor

import sys
sys.path.append("..")
from meta_stream import MetaStream

# %%
df = pd.read_csv("../../data/electricity-normalized.csv")
df = df[['period', 'nswprice', 'nswdemand', 'vicprice', 'vicdemand', 'transfer']]

# %%
# NOTE: list of regression algorithms
models =    [
            SVR(),
            RandomForestRegressor(random_state=42),
            LinearRegression(),
            Ridge(),
            GradientBoostingRegressor(random_state=42),
            DecisionTreeRegressor()
            ]

# %%
model_names = {
    type(SVR()).__name__: 'SVR',
    type(RandomForestRegressor()).__name__: 'RF',
    type(LinearRegression()).__name__: 'LR',
    type(Ridge()).__name__: 'RIDGE',
    type(GradientBoostingRegressor()).__name__: 'GBR',
    type(DecisionTreeRegressor()).__name__: 'DTR',
}

# %% [markdown]
# Parameter settings for MetaStream (considering a meta-level window size of 200)

# %%
base_data_window = 96*2
base_delay_window = 0
base_sel_window_size = 48*2
meta_data_window = 200
threshold = 0.1

# %%
pair_list = []
metastream_score = []
default_score = []

# %%
meta_learner = RandomForestClassifier()
for pair in combinations(models, 2):
    reg1_name = type(pair[0]).__name__
    reg2_name = type(pair[1]).__name__
    print(f'Regressor pair: {reg1_name}, {reg2_name}')
    
    metas = MetaStream(meta_learner, pair, base_data_window, base_delay_window, base_sel_window_size, meta_data_window, strategy='combination', default=True, ensemble=True, pairs=True)
    metas.base_train(data=df, target='nswdemand')
    metas.meta_train(data=df, target='nswdemand')
    
    metas.print_results()
    base, meta = metas.get_results()
    
    pair_list.append(f'{model_names[reg1_name]}/{model_names[reg2_name]}')
    metastream_score.append(meta['recommended'])
    default_score.append(meta['default'])
    
    print('######################################################################')
# Out:
# Regressor pair: SVR, RandomForestRegressor
# Mean score recommended 0.386+-0.386
# Meta-level score recommended 0.574
# Mean score default 0.338+-0.373
# Meta-level score default 0.407
# Mean score ensemble 0.420+-0.429
# Mean score regressor 1 0.694
# Mean score regressor 2 0.338
# ######################################################################
# Regressor pair: SVR, LinearRegression
# Mean score recommended 0.428+-0.349
# Meta-level score recommended 0.544
# Mean score default 0.694+-0.689
# Meta-level score default 0.770
# Mean score ensemble 0.427+-0.349
# Mean score regressor 1 0.694
# Mean score regressor 2 0.429
# ######################################################################
# Regressor pair: SVR, Ridge
# Mean score recommended 0.690+-0.724
# Meta-level score recommended 0.630
# Mean score default 0.694+-0.689
# Meta-level score default 0.570
# Mean score ensemble 0.669+-0.687
# Mean score regressor 1 0.694
# Mean score regressor 2 0.752
# ######################################################################
# Regressor pair: SVR, GradientBoostingRegressor
# Mean score recommended 0.366+-0.390
# Meta-level score recommended 0.622
# Mean score default 0.286+-0.309
# Meta-level score default 0.341
# Mean score ensemble 0.387+-0.398
# Mean score regressor 1 0.694
# Mean score regressor 2 0.286
# ######################################################################
# Regressor pair: SVR, DecisionTreeRegressor
# Mean score recommended 0.413+-0.375
# Meta-level score recommended 0.452
# Mean score default 0.421+-0.384
# Meta-level score default 0.415
# Mean score ensemble 0.420+-0.380
# Mean score regressor 1 0.694
# Mean score regressor 2 0.389
# ######################################################################
# Regressor pair: RandomForestRegressor, LinearRegression
# Mean score recommended 0.319+-0.328
# Meta-level score recommended 0.581
# Mean score default 0.338+-0.373
# Meta-level score default 0.519
# Mean score ensemble 0.310+-0.308
# Mean score regressor 1 0.338
# Mean score regressor 2 0.429
# ######################################################################
# Regressor pair: RandomForestRegressor, Ridge
# Mean score recommended 0.400+-0.470
# Meta-level score recommended 0.596
# Mean score default 0.338+-0.373
# Meta-level score default 0.367
# Mean score ensemble 0.429+-0.484
# Mean score regressor 1 0.338
# Mean score regressor 2 0.752
# ######################################################################
# Regressor pair: RandomForestRegressor, GradientBoostingRegressor
# Mean score recommended 0.287+-0.310
# Meta-level score recommended 0.407
# Mean score default 0.286+-0.309
# Meta-level score default 0.385
# Mean score ensemble 0.302+-0.329
# Mean score regressor 1 0.338
# Mean score regressor 2 0.286
# ######################################################################
# Regressor pair: RandomForestRegressor, DecisionTreeRegressor
# Mean score recommended 0.346+-0.352
# Meta-level score recommended 0.733
# Mean score default 0.338+-0.373
# Meta-level score default 0.219
# Mean score ensemble 0.349+-0.356
# Mean score regressor 1 0.338
# Mean score regressor 2 0.390
# ######################################################################
# Regressor pair: LinearRegression, Ridge
# Mean score recommended 0.477+-0.390
# Meta-level score recommended 0.607
# Mean score default 0.429+-0.367
# Meta-level score default 0.552
# Mean score ensemble 0.476+-0.399
# Mean score regressor 1 0.429
# Mean score regressor 2 0.752
# ######################################################################
# Regressor pair: LinearRegression, GradientBoostingRegressor
# Mean score recommended 0.275+-0.273
# Meta-level score recommended 0.619
# Mean score default 0.286+-0.309
# Meta-level score default 0.441
# Mean score ensemble 0.276+-0.273
# Mean score regressor 1 0.429
# Mean score regressor 2 0.286
# ######################################################################
# Regressor pair: LinearRegression, DecisionTreeRegressor
# Mean score recommended 0.322+-0.292
# Meta-level score recommended 0.389
# Mean score default 0.321+-0.294
# Meta-level score default 0.385
# Mean score ensemble 0.320+-0.294
# Mean score regressor 1 0.429
# Mean score regressor 2 0.385
# ######################################################################
# Regressor pair: Ridge, GradientBoostingRegressor
# Mean score recommended 0.365+-0.410
# Meta-level score recommended 0.637
# Mean score default 0.286+-0.309
# Meta-level score default 0.311
# Mean score ensemble 0.386+-0.422
# Mean score regressor 1 0.752
# Mean score regressor 2 0.286
# ######################################################################
# Regressor pair: Ridge, DecisionTreeRegressor
# Mean score recommended 0.424+-0.407
# Meta-level score recommended 0.363
# Mean score default 0.384+-0.338
# Meta-level score default 0.733
# Mean score ensemble 0.424+-0.407
# Mean score regressor 1 0.752
# Mean score regressor 2 0.391
# ######################################################################
# Regressor pair: GradientBoostingRegressor, DecisionTreeRegressor
# Mean score recommended 0.311+-0.306
# Meta-level score recommended 0.826
# Mean score default 0.286+-0.309
# Meta-level score default 0.178
# Mean score ensemble 0.317+-0.312
# Mean score regressor 1 0.286
# Mean score regressor 2 0.387
# ######################################################################

# %%
bar_width = 0.3
bar_locs = np.arange(len(pair_list))

plt.figure(figsize=(15,10))
plt.bar(bar_locs, metastream_score, width=bar_width, color='r', label='MetaStream')
plt.bar(bar_locs+bar_width, default_score, width=bar_width, color='b', label='Default')

plt.xticks(bar_locs+bar_width/2, pair_list, fontsize=14, rotation=90)
plt.xlabel('Regressor pairs', fontsize=20)

plt.yticks(fontsize=14)
plt.ylim(0, 1)
plt.ylabel('Meta-level error rate', fontsize=20)

plt.legend(loc='best', borderpad=1, fontsize=15)
plt.show()
